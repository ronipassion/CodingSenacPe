# %%
def soma(n1, n2):
    return n1 + n2

def subtrai(n1, n2):
    return n1 - n2

def multiplica(n1, n2):
    return n1 * n2

def divide(n1, n2):
    return n1 / n2

def exponenciacao(n1, n2):
    return n1 ** n2

def raizQuadrada(n1):
    return n1 ** (1/2)

def restoDivisao(n1, n2):
    return n1 % n2

# %%
while True:
    print("+===============================+")
    print("| ESCOLHA UMA DAS OPÇÕES ABAIXO |")
    print("|          1 - Somar            |")
    print("|          2 - Subtrair         |")
    print("|          3 - Multiplicar      |")
    print("|          4 - Dividir          |")
    print("|          5 - Exponenciação    |")
    print("|          6 - Raiz quadrada    |")
    print("|          7 - Resto da divisão |")
    print("|          0 - Sair             |")
    print("+===============================+")

    op = int(input())
    if op == 0:
        break
    if (op <= 7):
        if (op == 6):
           n1 = int(input("Digite o número"))
           print("O resultado da raíz quadrada é: ", raizQuadrada(n1))
           escolha = int(input("Digite 1 para continuar ou 0 para sair!"))
           if (escolha == 0):
               break
        else:
            n1 = int(input("Primeiro número: "))
            n2 = int(input("Segundo número: "))

            if op == 1:
                print("O resultado da soma é:", soma(n1, n2))
            elif op == 2:
                print("O resultado da subtração é:", subtrai(n1, n2))
            elif op == 3:
                print("O resultado da multiplicação é:", multiplica(n1, n2))
            elif op == 4:
                print("O resultado da divisão é:", divide(n1, n2))
            elif op == 5:
                print("O resultado da exponenciação é: ", exponenciacao(n1, n2))
            elif op == 7:
                print("O resto da divisão é:", restoDivisao(n1, n2))     
    else:    
      print("Opção inválida. Tente novamente!")
# Out:
# +===============================+
# | ESCOLHA UMA DAS OPÇÕES ABAIXO |
# |          1 - Somar            |
# |          2 - Subtrair         |
# |          3 - Multiplicar      |
# |          4 - Dividir          |
# |          5 - Exponenciação    |
# |          6 - Raiz quadrada    |
# |          7 - Resto da divisão |
# |          0 - Sair             |
# +===============================+
# O resultado da raíz quadrada é:  3.0
# +===============================+
# | ESCOLHA UMA DAS OPÇÕES ABAIXO |
# |          1 - Somar            |
# |          2 - Subtrair         |
# |          3 - Multiplicar      |
# |          4 - Dividir          |
# |          5 - Exponenciação    |
# |          6 - Raiz quadrada    |
# |          7 - Resto da divisão |
# |          0 - Sair             |
# +===============================+
# O resultado da exponenciação é:  8
# +===============================+
# | ESCOLHA UMA DAS OPÇÕES ABAIXO |
# |          1 - Somar            |
# ...
